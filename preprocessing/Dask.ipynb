# %%
conda install dask
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/kevin/anaconda3/envs/language
#
#   added / updated specs:
#     - dask
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.0.2                |           py38_0         5.3 MB
#     click-7.1.2                |             py_0          71 KB
#     cloudpickle-1.4.1          |             py_0          30 KB
#     cytoolz-0.10.1             |   py38h7b6447c_0         392 KB
#     dask-2.17.2                |             py_0          14 KB
#     dask-core-2.17.2           |             py_0         585 KB
#     distributed-2.17.0         |           py38_0         998 KB
#     fsspec-0.7.4               |             py_0          63 KB
#     libtiff-4.1.0              |       h2733197_0         447 KB
#     locket-0.2.0               |           py38_1           9 KB
#     msgpack-python-1.0.0       |   py38hfd86e86_1          91 KB
#     olefile-0.46               |             py_0          33 KB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     partd-1.1.0                |             py_0          20 KB
#     pillow-7.1.2               |   py38hb39fc2d_0         605 KB
#     psutil-5.7.0               |   py38h7b6447c_0         321 KB
#     pyyaml-5.3.1               |   py38h7b6447c_0         185 KB
#     sortedcontainers-2.1.0     |           py38_0          42 KB
#     tblib-1.6.0                |             py_0          16 KB
#     toolz-0.10.0               |             py_0          52 KB
#     typing_extensions-3.7.4.1  |           py38_0          40 KB
#     zict-2.0.0                 |             py_0          13 KB
#     ------------------------------------------------------------
#                                            Total:        11.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   bokeh              pkgs/main/linux-64::bokeh-2.0.2-py38_0
#   click              pkgs/main/noarch::click-7.1.2-py_0
#   cloudpickle        pkgs/main/noarch::cloudpickle-1.4.1-py_0
#   cytoolz            pkgs/main/linux-64::cytoolz-0.10.1-py38h7b6447c_0
#   dask               pkgs/main/noarch::dask-2.17.2-py_0
#   dask-core          pkgs/main/noarch::dask-core-2.17.2-py_0
#   distributed        pkgs/main/linux-64::distributed-2.17.0-py38_0
#   freetype           pkgs/main/linux-64::freetype-2.9.1-h8a8886c_1
#   fsspec             pkgs/main/noarch::fsspec-0.7.4-py_0
#   heapdict           pkgs/main/noarch::heapdict-1.0.1-py_0
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_0
#   locket             pkgs/main/linux-64::locket-0.2.0-py38_1
#   msgpack-python     pkgs/main/linux-64::msgpack-python-1.0.0-py38hfd86e86_1
#   olefile            pkgs/main/noarch::olefile-0.46-py_0
#   partd              pkgs/main/noarch::partd-1.1.0-py_0
#   pillow             pkgs/main/linux-64::pillow-7.1.2-py38hb39fc2d_0
#   psutil             pkgs/main/linux-64::psutil-5.7.0-py38h7b6447c_0
#   pyyaml             pkgs/main/linux-64::pyyaml-5.3.1-py38h7b6447c_0
#   sortedcontainers   pkgs/main/linux-64::sortedcontainers-2.1.0-py38_0
#   tblib              pkgs/main/noarch::tblib-1.6.0-py_0
#   toolz              pkgs/main/noarch::toolz-0.10.0-py_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-3.7.4.1-py38_0
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zict               pkgs/main/noarch::zict-2.0.0-py_0
#   zstd               pkgs/main/linux-64::zstd-1.3.7-h0b5b093_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.4.5~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.4.5.1-py38h~ --> pkgs/main::certifi-2020.4.5.1-py38_0
#   openssl            conda-forge::openssl-1.1.1g-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# partd-1.1.0          | 20 KB     | ##################################### | 100%
# sortedcontainers-2.1 | 42 KB     | ##################################### | 100%
# tblib-1.6.0          | 16 KB     | ##################################### | 100%
# psutil-5.7.0         | 321 KB    | ##################################### | 100%
# libtiff-4.1.0        | 447 KB    | ##################################### | 100%
# distributed-2.17.0   | 998 KB    | ##################################### | 100%
# locket-0.2.0         | 9 KB      | ##################################### | 100%
# click-7.1.2          | 71 KB     | ##################################### | 100%
# olefile-0.46         | 33 KB     | ##################################### | 100%
# toolz-0.10.0         | 52 KB     | ##################################### | 100%
# dask-2.17.2          | 14 KB     | ##################################### | 100%
# typing_extensions-3. | 40 KB     | ##################################### | 100%
# msgpack-python-1.0.0 | 91 KB     | ##################################### | 100%
# dask-core-2.17.2     | 585 KB    | ##################################### | 100%
# fsspec-0.7.4         | 63 KB     | ##################################### | 100%
# bokeh-2.0.2          | 5.3 MB    | ##################################### | 100%
# zict-2.0.0           | 13 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.5 MB    | ##################################### | 100%
# cloudpickle-1.4.1    | 30 KB     | ##################################### | 100%
# pyyaml-5.3.1         | 185 KB    | ##################################### | 100%
# pillow-7.1.2         | 605 KB    | ##################################### | 100%
# cytoolz-0.10.1       | 392 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from dask.distributed import Client, progress
client = Client(n_workers=2, threads_per_worker=2, memory_limit='1GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:39083' processes=2 threads=4, memory=2.00 GB>
