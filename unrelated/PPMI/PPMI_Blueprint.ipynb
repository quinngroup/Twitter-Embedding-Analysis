# %%
import os, math
import dask.dataframe as dd
import pandas as pd
import numpy as np
from scipy.sparse import lil_matrix, hstack

# %%
masterx2i, masteri2x = {}, {}
counter = 0

# %%
def createDict(file_name):
    global counter
    print(file_name)
    wc = pd.read_csv("wc2/wc_"+file_name+'.csv')
    wc = wc.drop("Unnamed: 0", axis=1)
    wc.columns = ["word", "count"]
    # print(wc)
    for index, row in wc.iterrows():
        
        if index % 100 == 0:
            print(f'finished indexing {index/len(wc):.2%} of vocab')
        
        if row["word"] not in masterx2i.keys():
            masterx2i[row["word"]] = counter
            masteri2x[counter] = row["word"]
            counter = counter+1
            # print(counter)

# %%
createDict("2018-01-22")
# Out:
# 2018-01-22
# finished indexing 0.00% of vocab
# finished indexing 0.25% of vocab
# finished indexing 0.50% of vocab
# finished indexing 0.75% of vocab
# finished indexing 1.00% of vocab
# finished indexing 1.25% of vocab
# finished indexing 1.50% of vocab
# finished indexing 1.75% of vocab
# finished indexing 2.00% of vocab
# finished indexing 2.25% of vocab
# finished indexing 2.50% of vocab
# finished indexing 2.76% of vocab
# finished indexing 3.01% of vocab
# finished indexing 3.26% of vocab
# finished indexing 3.51% of vocab
# finished indexing 3.76% of vocab
# finished indexing 4.01% of vocab
# finished indexing 4.26% of vocab
# finished indexing 4.51% of vocab
# finished indexing 4.76% of vocab
# finished indexing 5.01% of vocab
# finished indexing 5.26% of vocab
# finished indexing 5.51% of vocab
# finished indexing 5.76% of vocab
# finished indexing 6.01% of vocab
# finished indexing 6.26% of vocab
# finished indexing 6.51% of vocab
# finished indexing 6.76% of vocab
# finished indexing 7.01% of vocab
# finished indexing 7.26% of vocab
# finished indexing 7.51% of vocab
# finished indexing 7.76% of vocab
# finished indexing 8.02% of vocab
# finished indexing 8.27% of vocab
# finished indexing 8.52% of vocab
# finished indexing 8.77% of vocab
# finished indexing 9.02% of vocab
# finished indexing 9.27% of vocab
# finished indexing 9.52% of vocab
# finished indexing 9.77% of vocab
# finished indexing 10.02% of vocab
# finished indexing 10.27% of vocab
# finished indexing 10.52% of vocab
# finished indexing 10.77% of vocab
# finished indexing 11.02% of vocab
# finished indexing 11.27% of vocab
# finished indexing 11.52% of vocab
# finished indexing 11.77% of vocab
# finished indexing 12.02% of vocab
# finished indexing 12.27% of vocab
# finished indexing 12.52% of vocab
# finished indexing 12.77% of vocab
# finished indexing 13.02% of vocab
# finished indexing 13.28% of vocab
# finished indexing 13.53% of vocab
# finished indexing 13.78% of vocab
# finished indexing 14.03% of vocab
# finished indexing 14.28% of vocab
# finished indexing 14.53% of vocab
# finished indexing 14.78% of vocab
# finished indexing 15.03% of vocab
# finished indexing 15.28% of vocab
# finished indexing 15.53% of vocab
# finished indexing 15.78% of vocab
# finished indexing 16.03% of vocab
# finished indexing 16.28% of vocab
# finished indexing 16.53% of vocab
# finished indexing 16.78% of vocab
# finished indexing 17.03% of vocab
# finished indexing 17.28% of vocab
# finished indexing 17.53% of vocab
# finished indexing 17.78% of vocab
# finished indexing 18.03% of vocab
# finished indexing 18.28% of vocab
# finished indexing 18.54% of vocab
# finished indexing 18.79% of vocab
# finished indexing 19.04% of vocab
# finished indexing 19.29% of vocab
# finished indexing 19.54% of vocab
# finished indexing 19.79% of vocab
# finished indexing 20.04% of vocab
# finished indexing 20.29% of vocab
# finished indexing 20.54% of vocab
# finished indexing 20.79% of vocab
# finished indexing 21.04% of vocab
# finished indexing 21.29% of vocab
# finished indexing 21.54% of vocab
# finished indexing 21.79% of vocab
# finished indexing 22.04% of vocab
# finished indexing 22.29% of vocab
# finished indexing 22.54% of vocab
# finished indexing 22.79% of vocab
# finished indexing 23.04% of vocab
# finished indexing 23.29% of vocab
# finished indexing 23.54% of vocab
# finished indexing 23.80% of vocab
# finished indexing 24.05% of vocab
# finished indexing 24.30% of vocab
# finished indexing 24.55% of vocab
# finished indexing 24.80% of vocab
# finished indexing 25.05% of vocab
# finished indexing 25.30% of vocab
# finished indexing 25.55% of vocab
# finished indexing 25.80% of vocab
# finished indexing 26.05% of vocab
# finished indexing 26.30% of vocab
# finished indexing 26.55% of vocab
# finished indexing 26.80% of vocab
# finished indexing 27.05% of vocab
# finished indexing 27.30% of vocab
# finished indexing 27.55% of vocab
# finished indexing 27.80% of vocab
# finished indexing 28.05% of vocab
# finished indexing 28.30% of vocab
# finished indexing 28.55% of vocab
# finished indexing 28.80% of vocab
# finished indexing 29.06% of vocab
# finished indexing 29.31% of vocab
# finished indexing 29.56% of vocab
# finished indexing 29.81% of vocab
# finished indexing 30.06% of vocab
# finished indexing 30.31% of vocab
# finished indexing 30.56% of vocab
# finished indexing 30.81% of vocab
# finished indexing 31.06% of vocab
# finished indexing 31.31% of vocab
# finished indexing 31.56% of vocab
# finished indexing 31.81% of vocab
# finished indexing 32.06% of vocab
# finished indexing 32.31% of vocab
# finished indexing 32.56% of vocab
# finished indexing 32.81% of vocab
# finished indexing 33.06% of vocab
# finished indexing 33.31% of vocab
# finished indexing 33.56% of vocab
# finished indexing 33.81% of vocab
# finished indexing 34.06% of vocab
# finished indexing 34.32% of vocab
# finished indexing 34.57% of vocab
# finished indexing 34.82% of vocab
# finished indexing 35.07% of vocab
# finished indexing 35.32% of vocab
# finished indexing 35.57% of vocab
# finished indexing 35.82% of vocab
# finished indexing 36.07% of vocab
# finished indexing 36.32% of vocab
# finished indexing 36.57% of vocab
# finished indexing 36.82% of vocab
# finished indexing 37.07% of vocab
# finished indexing 37.32% of vocab
# finished indexing 37.57% of vocab
# finished indexing 37.82% of vocab
# finished indexing 38.07% of vocab
# finished indexing 38.32% of vocab
# finished indexing 38.57% of vocab
# finished indexing 38.82% of vocab
# finished indexing 39.07% of vocab
# finished indexing 39.32% of vocab
# finished indexing 39.58% of vocab
# finished indexing 39.83% of vocab
# finished indexing 40.08% of vocab
# finished indexing 40.33% of vocab
# finished indexing 40.58% of vocab
# finished indexing 40.83% of vocab
# finished indexing 41.08% of vocab
# finished indexing 41.33% of vocab
# finished indexing 41.58% of vocab
# finished indexing 41.83% of vocab
# finished indexing 42.08% of vocab
# finished indexing 42.33% of vocab
# finished indexing 42.58% of vocab
# finished indexing 42.83% of vocab
# finished indexing 43.08% of vocab
# finished indexing 43.33% of vocab
# finished indexing 43.58% of vocab
# finished indexing 43.83% of vocab
# finished indexing 44.08% of vocab
# finished indexing 44.33% of vocab
# finished indexing 44.58% of vocab
# finished indexing 44.84% of vocab
# finished indexing 45.09% of vocab
# finished indexing 45.34% of vocab
# finished indexing 45.59% of vocab
# finished indexing 45.84% of vocab
# finished indexing 46.09% of vocab
# finished indexing 46.34% of vocab
# finished indexing 46.59% of vocab
# finished indexing 46.84% of vocab
# finished indexing 47.09% of vocab
# finished indexing 47.34% of vocab
# finished indexing 47.59% of vocab
# finished indexing 47.84% of vocab
# finished indexing 48.09% of vocab
# finished indexing 48.34% of vocab
# finished indexing 48.59% of vocab
# finished indexing 48.84% of vocab
# finished indexing 49.09% of vocab
# finished indexing 49.34% of vocab
# finished indexing 49.59% of vocab
# finished indexing 49.84% of vocab
# finished indexing 50.10% of vocab
# finished indexing 50.35% of vocab
# finished indexing 50.60% of vocab
# finished indexing 50.85% of vocab
# finished indexing 51.10% of vocab
# finished indexing 51.35% of vocab
# finished indexing 51.60% of vocab
# finished indexing 51.85% of vocab
# finished indexing 52.10% of vocab
# finished indexing 52.35% of vocab
# finished indexing 52.60% of vocab
# finished indexing 52.85% of vocab
# finished indexing 53.10% of vocab
# finished indexing 53.35% of vocab
# finished indexing 53.60% of vocab
# finished indexing 53.85% of vocab
# finished indexing 54.10% of vocab
# finished indexing 54.35% of vocab
# finished indexing 54.60% of vocab
# finished indexing 54.85% of vocab
# finished indexing 55.10% of vocab
# finished indexing 55.36% of vocab
# finished indexing 55.61% of vocab
# finished indexing 55.86% of vocab
# finished indexing 56.11% of vocab
# finished indexing 56.36% of vocab
# finished indexing 56.61% of vocab
# finished indexing 56.86% of vocab
# finished indexing 57.11% of vocab
# finished indexing 57.36% of vocab
# finished indexing 57.61% of vocab
# finished indexing 57.86% of vocab
# finished indexing 58.11% of vocab
# finished indexing 58.36% of vocab
# finished indexing 58.61% of vocab
# finished indexing 58.86% of vocab
# finished indexing 59.11% of vocab
# finished indexing 59.36% of vocab
# finished indexing 59.61% of vocab
# finished indexing 59.86% of vocab
# finished indexing 60.11% of vocab
# finished indexing 60.36% of vocab
# finished indexing 60.62% of vocab
# finished indexing 60.87% of vocab
# finished indexing 61.12% of vocab
# finished indexing 61.37% of vocab
# finished indexing 61.62% of vocab
# finished indexing 61.87% of vocab
# finished indexing 62.12% of vocab
# finished indexing 62.37% of vocab
# finished indexing 62.62% of vocab
# finished indexing 62.87% of vocab
# finished indexing 63.12% of vocab
# finished indexing 63.37% of vocab
# finished indexing 63.62% of vocab
# finished indexing 63.87% of vocab
# finished indexing 64.12% of vocab
# finished indexing 64.37% of vocab
# finished indexing 64.62% of vocab
# finished indexing 64.87% of vocab
# finished indexing 65.12% of vocab
# finished indexing 65.37% of vocab
# finished indexing 65.62% of vocab
# finished indexing 65.88% of vocab
# finished indexing 66.13% of vocab
# finished indexing 66.38% of vocab
# finished indexing 66.63% of vocab
# finished indexing 66.88% of vocab
# finished indexing 67.13% of vocab
# finished indexing 67.38% of vocab
# finished indexing 67.63% of vocab
# finished indexing 67.88% of vocab
# finished indexing 68.13% of vocab
# finished indexing 68.38% of vocab
# finished indexing 68.63% of vocab
# finished indexing 68.88% of vocab
# finished indexing 69.13% of vocab
# finished indexing 69.38% of vocab
# finished indexing 69.63% of vocab
# finished indexing 69.88% of vocab
# finished indexing 70.13% of vocab
# finished indexing 70.38% of vocab
# finished indexing 70.63% of vocab
# finished indexing 70.88% of vocab
# finished indexing 71.14% of vocab
# finished indexing 71.39% of vocab
# finished indexing 71.64% of vocab
# finished indexing 71.89% of vocab
# finished indexing 72.14% of vocab
# finished indexing 72.39% of vocab
# finished indexing 72.64% of vocab
# finished indexing 72.89% of vocab
# finished indexing 73.14% of vocab
# finished indexing 73.39% of vocab
# finished indexing 73.64% of vocab
# finished indexing 73.89% of vocab
# finished indexing 74.14% of vocab
# finished indexing 74.39% of vocab
# finished indexing 74.64% of vocab
# finished indexing 74.89% of vocab
# finished indexing 75.14% of vocab
# finished indexing 75.39% of vocab
# finished indexing 75.64% of vocab
# finished indexing 75.89% of vocab
# finished indexing 76.14% of vocab
# finished indexing 76.40% of vocab
# finished indexing 76.65% of vocab
# finished indexing 76.90% of vocab
# finished indexing 77.15% of vocab
# finished indexing 77.40% of vocab
# finished indexing 77.65% of vocab
# finished indexing 77.90% of vocab
# finished indexing 78.15% of vocab
# finished indexing 78.40% of vocab
# finished indexing 78.65% of vocab
# finished indexing 78.90% of vocab
# finished indexing 79.15% of vocab
# finished indexing 79.40% of vocab
# finished indexing 79.65% of vocab
# finished indexing 79.90% of vocab
# finished indexing 80.15% of vocab
# finished indexing 80.40% of vocab
# finished indexing 80.65% of vocab
# finished indexing 80.90% of vocab
# finished indexing 81.15% of vocab
# finished indexing 81.40% of vocab
# finished indexing 81.66% of vocab
# finished indexing 81.91% of vocab
# finished indexing 82.16% of vocab
# finished indexing 82.41% of vocab
# finished indexing 82.66% of vocab
# finished indexing 82.91% of vocab
# finished indexing 83.16% of vocab
# finished indexing 83.41% of vocab
# finished indexing 83.66% of vocab
# finished indexing 83.91% of vocab
# finished indexing 84.16% of vocab
# finished indexing 84.41% of vocab
# finished indexing 84.66% of vocab
# finished indexing 84.91% of vocab
# finished indexing 85.16% of vocab
# finished indexing 85.41% of vocab
# finished indexing 85.66% of vocab
# finished indexing 85.91% of vocab
# finished indexing 86.16% of vocab
# finished indexing 86.41% of vocab
# finished indexing 86.66% of vocab
# finished indexing 86.92% of vocab
# finished indexing 87.17% of vocab
# finished indexing 87.42% of vocab
# finished indexing 87.67% of vocab
# finished indexing 87.92% of vocab
# finished indexing 88.17% of vocab
# finished indexing 88.42% of vocab
# finished indexing 88.67% of vocab
# finished indexing 88.92% of vocab
# finished indexing 89.17% of vocab
# finished indexing 89.42% of vocab
# finished indexing 89.67% of vocab
# finished indexing 89.92% of vocab
# finished indexing 90.17% of vocab
# finished indexing 90.42% of vocab
# finished indexing 90.67% of vocab
# finished indexing 90.92% of vocab
# finished indexing 91.17% of vocab
# finished indexing 91.42% of vocab
# finished indexing 91.67% of vocab
# finished indexing 91.92% of vocab
# finished indexing 92.18% of vocab
# finished indexing 92.43% of vocab
# finished indexing 92.68% of vocab
# finished indexing 92.93% of vocab
# finished indexing 93.18% of vocab
# finished indexing 93.43% of vocab
# finished indexing 93.68% of vocab
# finished indexing 93.93% of vocab
# finished indexing 94.18% of vocab
# finished indexing 94.43% of vocab
# finished indexing 94.68% of vocab
# finished indexing 94.93% of vocab
# finished indexing 95.18% of vocab
# finished indexing 95.43% of vocab
# finished indexing 95.68% of vocab
# finished indexing 95.93% of vocab
# finished indexing 96.18% of vocab
# finished indexing 96.43% of vocab
# finished indexing 96.68% of vocab
# finished indexing 96.93% of vocab
# finished indexing 97.18% of vocab
# finished indexing 97.44% of vocab
# finished indexing 97.69% of vocab
# finished indexing 97.94% of vocab
# finished indexing 98.19% of vocab
# finished indexing 98.44% of vocab
# finished indexing 98.69% of vocab
# finished indexing 98.94% of vocab
# finished indexing 99.19% of vocab
# finished indexing 99.44% of vocab
# finished indexing 99.69% of vocab
# finished indexing 99.94% of vocab

# %%
wc = pd.read_csv("./wc2/wc_2018-01-22.csv")
wnd = pd.read_csv("./wnd2/wnd_2018-01-22.csv")

# %%
def delete_row_lil(mat, i):
    if not isinstance(mat, lil_matrix):
        raise ValueError("works only for LIL format -- use .tolil() first")
    mat.rows = np.delete(mat.rows, i)
    mat.data = np.delete(mat.data, i)
    mat._shape = (mat._shape[0] - 1, mat._shape[1])

# %%
def createMat(wc, wnd):
    
    curr_mat = lil_matrix(np.zeros((1,len(masterx2i)))) 
    
    for index, word1 in masteri2x.items():
        
        temp_row = np.zeros((1,len(masterx2i))) # the row in ppmi matrix
        
        for i in range(len(masteri2x)):
            
            word2 = masteri2x[i]
            
            wc1row = wc.loc[wc['0']==word1].values.tolist()
            wc2row = wc.loc[wc['0']==word2].values.tolist()
            wc1 = wc1row[0][2]   # word count word1
            wc2 = wc2row[0][2]   # word count word2
            
            wndw1q = wnd.loc[wnd['0']==word1]
            wndw2q = wndw1q.loc[wndw1q['1']==word2].values.tolist() # gets row for window count     
            try:
                wndc = wndw2q[0][3]
            except IndexError:    # if the words do not occur together then ppmi val should be 0
                temp_row[0][i] = 0
                break
            
            top = wndc * len(masteri2x)
            bot = wc1 * wc2
            val = math.log(float(top/bot),2) # calculate ppmi val
            
            if val < 0:
                val = 0
                
            temp_row[0][i] = val
        
        sm_temp = lil_matrix(temp_row)
        print(sm_temp.ndim)
        print(curr_mat.ndim)
        curr_mat = hstack(curr_mat, sm_temp) # stacks rows in top of each other
    
    delete_row_lil(curr_mat.tolil(), [-1])
    return curr_mat

# %%
ppmi = createMat(wc, wnd)
# Out:
# 2
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-64621634af80> in <module>()
# ----> 1 ppmi = createMat(wc, wnd)
#
# <ipython-input-146-58a19c8e303b> in createMat(wc, wnd)
#      36         print(sm_temp.ndim)
#      37         print(curr_mat.ndim)
# ---> 38         curr_mat = hstack(curr_mat, sm_temp) # stacks rows in top of each other
#      39
#      40     delete_row_lil(curr_mat.tolil(), [-1])
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/construct.py in hstack(blocks, format, dtype)
#     462
#     463     """
# --> 464     return bmat([blocks], format=format, dtype=dtype)
#     465
#     466
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/construct.py in bmat(blocks, format, dtype)
#     545
#     546     if blocks.ndim != 2:
# --> 547         raise ValueError('blocks must be 2-D')
#     548
#     549     M,N = blocks.shape
#
# ValueError: blocks must be 2-D
